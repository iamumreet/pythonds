# %%
import pandas as pd
data = pd.read_csv("../data/result.csv")
data
# Out:
#   STUDENT RESULT  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0             SN       NAME        ENG       MATH         SCI       POP
# 1               1     Amrit          56         87         78         78
# 2               2   Krishna          87         98         77         88
# 3               3      Gopal         12         65         75         76
# 4               4    Daniel          87         78         98         78
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0     TOTAL        PER      GRADE
# 1        299      74.75          B
# 2        350       87.5          A
# 3        228         57          C
# 4        341      85.25         B
