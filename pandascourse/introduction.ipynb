# %%
import pandas as pd
pd

# TWo types of data structures in pandas: Series and DataFrame

#Series: one-dimensional labeled array capable of holding any data 

# price = [100,200,300,400,500]
# data = pd.Series(price)
# data 


# price = [100,200,300,400,500]
# data = pd.Series(price)
# data[1]


# price = [100,200,300,400,500]
# data = pd.Series (price,index = ['apple', 'banana', 'mango', 'melon', 'grapes'])
# data


# price = [100,200,300,400,500]
# data = pd.Series (price,index = ['apple', 'banana', 'mango', 'melon', 'grapes'])
# data['banana']


# books = {
# 'title': ["79","Devil"],
# 'author':[ "Umreet Bardewa","Umreet Bardewa"],
# 'year': [2021,2035],
# 'price': [29.99,345.99],
# 'distribution ': "Dreamlens Productions"
# }
# data = pd.DataFrame(books)
# data 


# movies = {
#     'title': "Devil",
#     'director': "Umreet Bardewa",
#     'release date': 2035,
#     'Production': "UB Motion Pictures"
# }
# data = pd.Series(movies)
# data 

# users = [
#     ['Umreet Bardewa', 25, 'Male'],
#     ['Amrit Pariyar', 28, 'Male'],
#     ['Sunita Pariyar', 35, 'Female']
# ]
# data = pd.DataFrame(users, columns = ['Name', 'Age', 'Sex'])
# data
# Out:
#    title          author  year   price           distribution
# 0     79  Umreet Bardewa  2021   29.99  Dreamlens Productions
# 1  Devil  Umreet Bardewa  2035  345.99  Dreamlens Productions
