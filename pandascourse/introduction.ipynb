# %%
import pandas as pd
pd

# TWo types of data structures in pandas: Series and DataFrame

#Series: one-dimensional labeled array capable of holding any data 

# price = [100,200,300,400,500]
# Out:
# <module 'pandas' from 'c:\\Users\\hi\\AppData\\Local\\Programs\\Python\\Python314\\Lib\\site-packages\\pandas\\__init__.py'>
