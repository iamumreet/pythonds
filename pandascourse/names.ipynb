# %%
import pandas as pd
data = pd.DataFrame({
    "Name": ["Ram", "Hari", "Sita"],
    "Age": [25, 30, 28],
    "Salary": [50000, 60000, 55000]
})
data['Age']
data[data["Salary"] > 55000]

# %%
import pandas as pd
data =pd.read_csv("../data/names.csv")
# data.head()
data.describe()
data.isnull().sum()
# Out:
# Name          0
# Age           1
# Salary        1
# Department    1
# dtype: int64
