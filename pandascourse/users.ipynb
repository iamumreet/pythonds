# %%
import pandas as pd

category = pd.read_csv('../data/category.csv')
products = pd.read_csv('../data/products.csv')
orders = pd.read_csv('../data/orders.csv')
users = pd.read_csv('../data/users.csv')

join = pd.merge(orders, products, on='pid', how='left')

join
# Out:
#    sn  uid  pid  quantity_x  cid               title  quantity_y  price
# 0   1    1    1           2    1         HP Pavilion          10  50000
# 1   2    1    3           1    2           iPhone 12          20  70000
# 2   3    2    2           1    1     Lenovo ThinkPad          15  60000
# 3   4    3    4           1    2  Samsung Galaxy S21          25  65000
