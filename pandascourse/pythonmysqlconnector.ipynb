# %%
import pandas as pd
import mysql.connector

host = 'localhost'
user = 'root'
password = 'osrdigital23#'
# database = 'pythonclass'
database = 'country'
conn = mysql.connector.connect(host=host, user=user, password=password, database=database)
myCur= conn.cursor()

# myCur.execute('select * from products')
# myCur.execute('select * from category')
# myCur.execute('select country.Name as CountryName, Country.Code from country')
myCur.execute('select * from country')
CountryData = myCur.fetchall()
ConDf = pd.DataFrame(CountryData, columns = myCur.column_names)
ConDf['CountryName'] = ConDf['Name']
#drop the original 'Name' column 
ConDf.drop('Name', axis = 1, inplace = True)


myCur.execute("Select * from city")
cityData = myCur.fetchall()
cityDf= pd.DataFrame(cityData, columns = myCur.column_names)
cityDf
mergedDf = pd.merge(cityDf, ConDf, left_on = 'CountryCode', right_on = 'Code')
mergedDf

# df 
# df = pd.DataFrame(cityData, columns = myCur.column_names)
# df
# Out:
#         ID            Name CountryCode       District  Population_x Code  \
# 0        1           Kabul         AFG          Kabol       1780000  AFG
# 1        2        Qandahar         AFG       Qandahar        237500  AFG
# 2        3           Herat         AFG          Herat        186800  AFG
# 3        4  Mazar-e-Sharif         AFG          Balkh        127800  AFG
# 4        5       Amsterdam         NLD  Noord-Holland        731200  NLD
# ...    ...             ...         ...            ...           ...  ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis        123175  PSE
# 4075  4076          Hebron         PSE         Hebron        119401  PSE
# 4076  4077        Jabaliya         PSE     North Gaza        113901  PSE
# 4077  4078          Nablus         PSE         Nablus        100231  PSE
# 4078  4079           Rafah         PSE          Rafah         92020  PSE
#
#      Continent                     Region  SurfaceArea  IndepYear  \
# 0         Asia  Southern and Central Asia     652090.0     1919.0
# 1         Asia  Southern and Central Asia     652090.0     1919.0
# 2         Asia  Southern and Central Asia     652090.0     1919.0
# 3         Asia  Southern and Central Asia     652090.0     1919.0
# 4       Europe             Western Europe      41526.0     1581.0
# ...        ...                        ...          ...        ...
# 4074      Asia                Middle East       6257.0        NaN
# 4075      Asia                Middle East       6257.0        NaN
# 4076      Asia                Middle East       6257.0        NaN
# 4077      Asia                Middle East       6257.0        NaN
# 4078      Asia                Middle East       6257.0        NaN
#
#       Population_y  LifeExpectancy       GNP    GNPOld              LocalName  \
# 0         22720000            45.9    5976.0       NaN  Afganistan/Afqanestan
# 1         22720000            45.9    5976.0       NaN  Afganistan/Afqanestan
# 2         22720000            45.9    5976.0       NaN  Afganistan/Afqanestan
# 3         22720000            45.9    5976.0       NaN  Afganistan/Afqanestan
# 4         15864000            78.3  371362.0  360478.0              Nederland
# ...            ...             ...       ...       ...                    ...
# 4074       3101000            71.4    4173.0       NaN               Filastin
# 4075       3101000            71.4    4173.0       NaN               Filastin
# 4076       3101000            71.4    4173.0       NaN               Filastin
# 4077       3101000            71.4    4173.0       NaN               Filastin
# 4078       3101000            71.4    4173.0       NaN               Filastin
#
#                GovernmentForm            HeadOfState  Capital Code2  \
# 0             Islamic Emirate          Mohammad Omar      1.0    AF
# 1             Islamic Emirate          Mohammad Omar      1.0    AF
# 2             Islamic Emirate          Mohammad Omar      1.0    AF
# 3             Islamic Emirate          Mohammad Omar      1.0    AF
# 4     Constitutional Monarchy                Beatrix      5.0    NL
# ...                       ...                    ...      ...   ...
# 4074          Autonomous Area  Yasser (Yasir) Arafat   4074.0    PS
# 4075          Autonomous Area  Yasser (Yasir) Arafat   4074.0    PS
# 4076          Autonomous Area  Yasser (Yasir) Arafat   4074.0    PS
# 4077          Autonomous Area  Yasser (Yasir) Arafat   4074.0    PS
# 4078          Autonomous Area  Yasser (Yasir) Arafat   4074.0    PS
#
#       CountryName
# 0     Afghanistan
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Netherlands
# ...           ...
# 4074    Palestine
# 4075    Palestine
# 4076    Palestine
# 4077    Palestine
# 4078    Palestine
#
# [4079 rows x 20 columns]
