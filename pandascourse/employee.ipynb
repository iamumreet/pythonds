# %%
import pandas as pd
persons = [
    ['Genral Manager', 'Kumar KC', 50000],
    ['CEO', 'Umreet Bardewa', 100000],
    ['IT Head', 'Vishal Shrestha', 60000]

]
data = pd.DataFrame(persons, columns = ['Department', 'Employee', 'Salary'])
data 
avg_salary = data.groupby("Department")["Salary"].mean()
avg_salary
# Out:
# Department
# CEO               100000.0
# Genral Manager     50000.0
# IT Head            60000.0
# Name: Salary, dtype: float64
