# %%
import pandas as pd
data = pd.read_csv("../data/mob_sales.csv")
# data['Country']
# data.head(20)
data.tail(20)
# Out:
#      Sale_ID     Brand              Model    Country Storage   Color  \
# 480      481  Motorola  Motorola Model 10     France   256GB    Gold
# 481      482  Motorola  Motorola Model 20      India    64GB  Silver
# 482      483      Vivo      Vivo Model 19        USA   256GB  Silver
# 483      484    Xiaomi     Xiaomi Model 8        UAE   128GB   Black
# 484      485  Motorola   Motorola Model 8      India   512GB   Green
# 485      486      Oppo      Oppo Model 15        USA   128GB   Black
# 486      487    Huawei    Huawei Model 11     Canada   512GB   Green
# 487      488    Realme     Realme Model 6        UAE   512GB   White
# 488      489    Xiaomi    Xiaomi Model 20     Canada   256GB  Silver
# 489      490      Oppo      Oppo Model 12   Pakistan    64GB   Green
# 490      491  Motorola  Motorola Model 20     Canada   512GB   Black
# 491      492    Google     Google Model 7        USA    64GB   Green
# 492      493      Vivo      Vivo Model 12        USA   512GB   White
# ...
