# %%
import numpy as np
import matplotlib.pyplot as plt

laptops = np.array(['Dell', 'HP', 'Lenovo', 'Asus'])
prices = np.array([50000, 60000, 70000, 80000])
plt.plot(laptops, prices)
plt.show()
#data = np.array([12,31,51,71,61])
#def odd_num(n):
    #return n%2 != 0 
#data[odd_num(data)]
#data = ['We are learning numpy', 'it is very useful', 'numpy is fast']
#np.save('data.npy', data)
#np.savetxt('data.txt', data, fmt = '%s')
#string function
#np.char.upper(data)
#dir(np.char)
#np.char.count('We are learning numpy', 'n')
#np.char.split('We are learning numpy')
#data = np.zeros(20)
#data = np.ones(10)
#data

#data = np.array([12,34,56,76,67])
#data2 = np.array([56,76,67,87,78])
#data + data2
#np.add(data, data2)

#data = np.array([12,34,56,76,67])
#data -2 
#constants characters
#np.pi

#random numbers
#np.random.rand(5)

#math functions
#data = np.array([12,34,76,45,89,16])
#np.sqrt(data)

# %%
import numpy as np

#set function
data1 = np.array([12,34,56,76,67])
data2 = np.array([13,42,56,79,59])
 
np.intersect1d(data1,data2)
np.union1d(data1, data2)

#data time

#today = np.datetime64('today')
#today

#date = np.datetime64("2024-06-11")
date = np.datetime64("Today", "D")
date
# Out:
# np.datetime64('2026-02-26')
